# %%
import random
with open('names.txt',encoding='utf-8') as file:
    content=file.read()
names=content.split()
name=random.choices(names,k=50)
name
# Out:
# ['錢欣潔',
#  '李進慧',
#  '陳怡珊',
#  '朱士弘',
#  '昌嘉洋',
#  '葉軍仰',
#  '楊又源',
#  '劉耿琦',
#  '趙家豪',
#  '高士凱',
#  '賴佳雯',
#  '陳俊憲',
#  '黃心航',
#  '蒙淑惠',
#  '高信宏',
#  '胡姿婷',
#  '楊火帆',
#  '林群清',
#  '王筱婷',
#  '吳柏誠',
#  '葉軍仰',
#  '楊又源',
#  '黃名明',
#  '吳昕婷',
#  '黃柏宇',
#  '葉志峰',
#  '元延辛',
#  '林瑞喬',
#  '錢佩豪',
#  '趙宛真',
#  '黎惠雯',
#  '盧文啟',
#  '楊易政',
#  '謝南慧',
#  '游淑惠',
#  '林玉佩',
#  '張家秀',
#  '陳奇瑄',
#  '金宜芳',
#  '蔡明平',
#  '王泓泰',
#  '陳得映',
#  '王筱婷',
#  '楊又源',
#  '唐雪豪',
#  '張莉雯',
#  '蔡士賢',
#  '陳向愛',
#  '張韋成',
#  '張明惟']

# %%
import numpy as np
import pandas as pd

score1=np.random.randint(50,101,size=(50,5))
student1=pd.DataFrame(score1,
             columns=['國文','英文','數學','自然','社會'],
             index=name)
student1
# Out:
#       國文  英文  數學   自然  社會
# 錢欣潔   81  82  75   91  99
# 李進慧   76  79  94   99  62
# 陳怡珊   54  61  58   69  53
# 朱士弘  100  96  50   78  70
# 昌嘉洋   51  56  78   65  97
# 葉軍仰   71  53  87   72  72
# 楊又源   88  76  78   60  81
# 劉耿琦   62  69  71   75  72
# 趙家豪   94  72  91   52  91
# 高士凱   60  81  65   87  73
# 賴佳雯   60  62  60   57  73
# 陳俊憲   67  85  98   66  64
# 黃心航   79  68  70   91  85
# 蒙淑惠   77  64  74   67  74
# 高信宏   64  73  73   80  58
# 胡姿婷   89  70  64   88  80
# 楊火帆   71  93  76   59  81
# 林群清   52  87  65   75  83
# 王筱婷   50  52  61   60  98
# 吳柏誠   59  74  54   88  65
# 葉軍仰   64  62  65   61  52
# 楊又源   67  67  64   52  62
# 黃名明   66  93  79   76  95
# 吳昕婷   86  61  76   64  92
# 黃柏宇   65  88  87  100  51
# 葉志峰   93  79  51   56  79
# 元延辛   60  66  55   94  67
# 林瑞喬   89  71  57   56  99
# 錢佩豪   67  89  85   64  55
# 趙宛真   51  77  78   83  72
# 黎惠雯   80  69  78   77  53
# 盧文啟   52  69  60   62  73
# 楊易政   57  80  83   77  86
# 謝南慧   88  56  57   80  54
# ...

# %%
student1['國文'] + \
student1['英文'] + \
student1['數學'] + \
student1['自然'] + \
student1['社會']
# Out:
# 錢欣潔    428
# 李進慧    410
# 陳怡珊    295
# 朱士弘    394
# 昌嘉洋    347
# 葉軍仰    355
# 楊又源    383
# 劉耿琦    349
# 趙家豪    400
# 高士凱    366
# 賴佳雯    312
# 陳俊憲    380
# 黃心航    393
# 蒙淑惠    356
# 高信宏    348
# 胡姿婷    391
# 楊火帆    380
# 林群清    362
# 王筱婷    321
# 吳柏誠    340
# 葉軍仰    304
# 楊又源    312
# 黃名明    409
# 吳昕婷    379
# 黃柏宇    391
# 葉志峰    358
# 元延辛    342
# 林瑞喬    372
# 錢佩豪    360
# 趙宛真    361
# 黎惠雯    357
# 盧文啟    316
# 楊易政    383
# 謝南慧    335
# 游淑惠    369
# 林玉佩    370
# 張家秀    396
# 陳奇瑄    408
# 金宜芳    377
# 蔡明平    391
# 王泓泰    328
# 陳得映    358
# 王筱婷    368
# 楊又源    346
# 唐雪豪    438
# 張莉雯    373
# 蔡士賢    383
# 陳向愛    376
# 張韋成    381
# 張明惟    351
# dtype: int32

# %%
sum_series = student1['國文'] + \
student1['英文'] + \
student1['數學'] + \
student1['自然'] + \
student1['社會'] 
mean_series = sum_series / 5
mean_series
# Out:
# 錢欣潔    85.6
# 李進慧    82.0
# 陳怡珊    59.0
# 朱士弘    78.8
# 昌嘉洋    69.4
# 葉軍仰    71.0
# 楊又源    76.6
# 劉耿琦    69.8
# 趙家豪    80.0
# 高士凱    73.2
# 賴佳雯    62.4
# 陳俊憲    76.0
# 黃心航    78.6
# 蒙淑惠    71.2
# 高信宏    69.6
# 胡姿婷    78.2
# 楊火帆    76.0
# 林群清    72.4
# 王筱婷    64.2
# 吳柏誠    68.0
# 葉軍仰    60.8
# 楊又源    62.4
# 黃名明    81.8
# 吳昕婷    75.8
# 黃柏宇    78.2
# 葉志峰    71.6
# 元延辛    68.4
# 林瑞喬    74.4
# 錢佩豪    72.0
# 趙宛真    72.2
# 黎惠雯    71.4
# 盧文啟    63.2
# 楊易政    76.6
# 謝南慧    67.0
# 游淑惠    73.8
# 林玉佩    74.0
# 張家秀    79.2
# 陳奇瑄    81.6
# 金宜芳    75.4
# 蔡明平    78.2
# 王泓泰    65.6
# 陳得映    71.6
# 王筱婷    73.6
# 楊又源    69.2
# 唐雪豪    87.6
# 張莉雯    74.6
# 蔡士賢    76.6
# 陳向愛    75.2
# 張韋成    76.2
# 張明惟    70.2
# dtype: float64
